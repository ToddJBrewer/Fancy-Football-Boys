# %%
import pandas as pd

df = pd.read_csv("passing.tsv", sep='\t')

# %%
df
# Out:
#             Player Team  Gms  Att  Cmp   Pct    Yds  YPA  TD  TD%  Int  Int%  \
# 0  Patrick Mahomes   KC    9  366  245  66.9  2,936  8.0  25  6.8    7   1.9
# 1        Tom Brady   TB   10  427  282  66.0  2,805  6.6  12  2.8    2   0.5
# 2       Josh Allen  BUF    9  341  220  64.5  2,733  8.0  20  5.9   10   2.9
# 3       Joe Burrow  CIN    9  333  233  70.0  2,535  7.6  18  5.4    6   1.8
# 4       Geno Smith  SEA   10  316  230  72.8  2,474  7.8  17  5.4    4   1.3
# 5   Justin Herbert  LAC    9  386  254  65.8  2,450  6.3  14  3.6    6   1.6
# 6     Kirk Cousins  MIN    9  354  227  64.1  2,356  6.7  14  4.0    8   2.3
# 7  Trevor Lawrence  JAX   10  348  227  65.2  2,334  6.7  13  3.7    6   1.7
#
#     Lg  Sack  Loss   Rate
# 0   57    16   111  106.1
# 1   51    14   107   91.9
# 2  98t    18    93   96.6
# 3  60t    30   201  102.6
# 4   54    24   196  108.0
# 5   54    12    61   89.0
# 6   64    20   150   87.0
# 7   49    17   108   89.7

# %%
import matplotlib.pyplot as plt
df = df.head(32)
plt.figure(figsize=(40,20))
plt.scatter(df['Player'], df['Yds'])
plt.xlabel('Player')
plt.ylabel('Passing Yards')
plt.title('Passing Yards per Player')
plt.show()

# %%
df = df.head(16)
plt.figure(figsize=(30,20))
plt.scatter(df['Player'], df['YPA'])
plt.xlabel('Player')
plt.ylabel('Passing Yards')
plt.title('Passing Yards per Player')
plt.show()

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()
